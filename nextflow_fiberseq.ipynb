# %% [markdown]
# # Set up nextflow for Fiber-seq analysis
#
# https://nf-co.re/methylong/dev/docs/usage/

# %% [markdown]
# I ran this analysis on Midway3, and in python environment with fibertools installed. I installed fibertools using the following command:
#
# ```bash
# export USE_CONDA_CACHE=0
# module load python/miniforge-25.3.0
# export CONDA_PKGS_DIRS=/scratch/midway3/$USER/conda/pkgs
# conda create --prefix=/project/spott/cshan/envs/fire-env python=3.11
# source activate /project/spott/cshan/envs/fire-env
# mamba install -c conda-forge -c bioconda fibertools-rs
# ```

# %% [markdown]
# Nextflow is a workflow management system that enables scalable and reproducible scientific workflows. To set up Nextflow for Fiber-seq analysis, you can follow these steps:

# %%
# %%bash
# module load nextflow/24.10.6

# %% [markdown]
# ## 1.  Create sample sheet
#
# You will need to create a samplesheet with information about the samples you would like to analyse before running the pipeline. Use this parameter to specify its location. It has to be a comma-separated file with 5 columns, and a header row as shown in the examples below.
#
# ```
# --input '/path/to/samplesheet.csv'
# ```

# %% [markdown]
# To construct the sample sheet, we need to specify the following columns:
#
# - `group`: custom group name for the sample
# - `sample`: custom sample name for the sample
# - `path`: path to the input BAM file for the sample, this bam file gas to be unaligned bam file
